# %%
import matplotlib.pyplot as plt

plt.text(0.5, 0.5, r'$\vec{v}$', fontsize=20)
plt.title(r'Unit Vector $\hat{u}$')
# Out:
# Text(0.5, 1.0, 'Unit Vector $\\hat{u}$')

# %%
print("i\u0302")
# Out:
# î

# %%
print("v\u20d7")
# Out:
# v⃗

# %%
display(Math(r'\hat{v}'))
display(Math(r'\vec{v}'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 display(Math(r'\hat{v}'))
#       2 display(Math(r'\vec{v}'))
#
# NameError: name 'Math' is not defined

# %%
from IPython.display import display, Math

display(Math(r'\hat{v}'))
display(Math(r'\vec{v}'))
# Out:
# $\displaystyle \hat{v}$
# $\displaystyle \vec{v}$
