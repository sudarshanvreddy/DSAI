# %%
import sklearn
import skore
import skrub

skore.login()

data, target = sklearn.datasets.fetch_openml(
    data_id=42125, as_frame=True, return_X_y=True
)

report = skore.evaluate(
    skrub.tabular_pipeline("regressor"), data, target, splitter=0.2
)

project = skore.Project("sudarshan-workspace/my-first-project", mode="hub")
project.put("estimator", report)
# Out:
# ╭───────────────────────────────── Login to Skore Hub ─────────────────────────────────╮
# │                                                                                      │
# │                                  Already logged in.                                  │
# │                                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# Output()
# Consult your report at
# ]8;id=475853;https://skore.probabl.ai/sudarshan-workspace/my-first-project/estimators/7611\https://skore.probabl.ai/sudarshan-workspace/my-first-project/estimators/7611]8;;\
